# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df.stroke.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
df = df.dropna()
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5104       children          Rural             103.08  18.6          Unknown
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 12 columns]

# %%
df_smoke = df.loc[df.smoking_status != 'Unknown']
df_smoke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5100  68398    Male  82.0             1              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# 5102        Private          Rural              77.93  21.7     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5100       0
# 5102       0
# 5106       0
# 5107       0
# 5108       0
#
# [3426 rows x 12 columns]

# %%
df = df.drop(['id'], axis=1)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# 5             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08  18.6          Unknown       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [4909 rows x 11 columns]

# %%
df = df.astype({'age': int, 'avg_glucose_level': int, 'bmi':int})
df.dtypes
# Out:
# gender               object
# age                   int64
# hypertension          int64
# heart_disease         int64
# ever_married         object
# work_type            object
# Residence_type       object
# avg_glucose_level     int64
# bmi                   int64
# smoking_status       object
# stroke                int64
# dtype: object

# %%
df = pd.get_dummies(df, columns=['gender', 'ever_married', 'work_type', 'Residence_type', 
                                'smoking_status'])
df
# Out:
#       age  hypertension  heart_disease  avg_glucose_level  bmi  stroke  \
# 0      67             0              1                228   36       1
# 2      80             0              1                105   32       1
# 3      49             0              0                171   34       1
# 4      79             1              0                174   24       1
# 5      81             0              0                186   29       1
# ...   ...           ...            ...                ...  ...     ...
# 5104   13             0              0                103   18       0
# 5106   81             0              0                125   40       0
# 5107   35             0              0                 82   30       0
# 5108   51             0              0                166   25       0
# 5109   44             0              0                 85   26       0
#
#       gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 0                 0            1             0                0  ...
# 2                 0            1             0                0  ...
# 3                 1            0             0                0  ...
# 4                 1            0             0                0  ...
# 5                 0            1             0                0  ...
# ...             ...          ...           ...              ...  ...
# 5104              1            0             0                1  ...
# 5106              1            0             0                0  ...
# 5107              1            0             0                0  ...
# 5108              0            1             0                0  ...
# 5109              1            0             0                0  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                          0                  1                        0
# 2                          0                  1                        0
# 3                          0                  1                        0
# 4                          0                  0                        1
# 5                          0                  1                        0
# ...                      ...                ...                      ...
# 5104                       0                  0                        0
# 5106                       0                  0                        1
# 5107                       0                  0                        1
# 5108                       0                  1                        0
# 5109                       0                  0                        0
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                      0                     0                     1
# 2                      0                     1                     0
# 3                      0                     0                     1
# 4                      0                     1                     0
# 5                      0                     0                     1
# ...                  ...                   ...                   ...
# 5104                   1                     1                     0
# 5106                   0                     0                     1
# 5107                   0                     1                     0
# 5108                   0                     1                     0
# 5109                   0                     0                     1
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                          0                               1
# 2                          0                               0
# 3                          0                               0
# 4                          0                               0
# 5                          0                               1
# ...                      ...                             ...
# 5104                       1                               0
# 5106                       0                               0
# 5107                       0                               0
# 5108                       0                               1
# 5109                       1                               0
#
#       smoking_status_never smoked  smoking_status_smokes
# 0                               0                      0
# 2                               1                      0
# 3                               0                      1
# 4                               1                      0
# 5                               0                      0
# ...                           ...                    ...
# 5104                            0                      0
# 5106                            1                      0
# 5107                            1                      0
# 5108                            0                      0
# 5109                            0                      0
#
# [4909 rows x 22 columns]

# %%
df = df.sample(frac=1)
df
# Out:
#       age  hypertension  heart_disease  avg_glucose_level  bmi  stroke  \
# 4874   41             0              0                 87   30       0
# 2566    7             0              0                 86   17       0
# 3021   79             0              0                103   22       0
# 416     3             0              0                 73   16       0
# 72     66             1              0                116   31       1
# ...   ...           ...            ...                ...  ...     ...
# 2393   41             0              0                140   46       0
# 1415   37             0              0                120   33       0
# 2763   45             0              0                 63   32       0
# 3552   25             0              0                 66   29       0
# 2335   48             0              0                106   33       0
#
#       gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 4874              1            0             0                0  ...
# 2566              0            1             0                1  ...
# 3021              0            1             0                0  ...
# 416               1            0             0                1  ...
# 72                1            0             0                0  ...
# ...             ...          ...           ...              ...  ...
# 2393              1            0             0                0  ...
# 1415              0            1             0                0  ...
# 2763              1            0             0                0  ...
# 3552              0            1             0                0  ...
# 2335              0            1             0                0  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 4874                       0                  1                        0
# 2566                       0                  0                        0
# 3021                       0                  0                        1
# 416                        0                  0                        0
# 72                         0                  0                        0
# ...                      ...                ...                      ...
# 2393                       0                  1                        0
# 1415                       0                  1                        0
# 2763                       0                  1                        0
# 3552                       0                  1                        0
# 2335                       0                  1                        0
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 4874                   0                     0                     1
# 2566                   1                     0                     1
# 3021                   0                     1                     0
# 416                    1                     0                     1
# 72                     0                     1                     0
# ...                  ...                   ...                   ...
# 2393                   0                     0                     1
# 1415                   0                     0                     1
# 2763                   0                     1                     0
# 3552                   0                     1                     0
# 2335                   0                     1                     0
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 4874                       0                               0
# 2566                       1                               0
# 3021                       0                               1
# 416                        1                               0
# 72                         0                               1
# ...                      ...                             ...
# 2393                       1                               0
# 1415                       0                               0
# 2763                       1                               0
# 3552                       1                               0
# 2335                       0                               1
#
#       smoking_status_never smoked  smoking_status_smokes
# 4874                            1                      0
# 2566                            0                      0
# 3021                            0                      0
# 416                             0                      0
# 72                              0                      0
# ...                           ...                    ...
# 2393                            0                      0
# 1415                            0                      1
# 2763                            0                      0
# 3552                            0                      0
# 2335                            0                      0
#
# [4909 rows x 22 columns]

# %%
y = df['stroke']
X = df.drop(['stroke'], axis=1)

# %%
X
# Out:
#       age  hypertension  heart_disease  avg_glucose_level  bmi  gender_Female  \
# 4874   41             0              0                 87   30              1
# 2566    7             0              0                 86   17              0
# 3021   79             0              0                103   22              0
# 416     3             0              0                 73   16              1
# 72     66             1              0                116   31              1
# ...   ...           ...            ...                ...  ...            ...
# 2393   41             0              0                140   46              1
# 1415   37             0              0                120   33              0
# 2763   45             0              0                 63   32              1
# 3552   25             0              0                 66   29              0
# 2335   48             0              0                106   33              0
#
#       gender_Male  gender_Other  ever_married_No  ever_married_Yes  ...  \
# 4874            0             0                0                 1  ...
# 2566            1             0                1                 0  ...
# 3021            1             0                0                 1  ...
# 416             0             0                1                 0  ...
# 72              0             0                0                 1  ...
# ...           ...           ...              ...               ...  ...
# 2393            0             0                0                 1  ...
# 1415            1             0                0                 1  ...
# 2763            0             0                0                 1  ...
# 3552            1             0                0                 1  ...
# 2335            1             0                0                 1  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 4874                       0                  1                        0
# 2566                       0                  0                        0
# 3021                       0                  0                        1
# 416                        0                  0                        0
# 72                         0                  0                        0
# ...                      ...                ...                      ...
# 2393                       0                  1                        0
# 1415                       0                  1                        0
# 2763                       0                  1                        0
# 3552                       0                  1                        0
# 2335                       0                  1                        0
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 4874                   0                     0                     1
# 2566                   1                     0                     1
# 3021                   0                     1                     0
# 416                    1                     0                     1
# 72                     0                     1                     0
# ...                  ...                   ...                   ...
# 2393                   0                     0                     1
# 1415                   0                     0                     1
# 2763                   0                     1                     0
# 3552                   0                     1                     0
# 2335                   0                     1                     0
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 4874                       0                               0
# 2566                       1                               0
# 3021                       0                               1
# 416                        1                               0
# 72                         0                               1
# ...                      ...                             ...
# 2393                       1                               0
# 1415                       0                               0
# 2763                       1                               0
# 3552                       1                               0
# 2335                       0                               1
#
#       smoking_status_never smoked  smoking_status_smokes
# 4874                            1                      0
# 2566                            0                      0
# 3021                            0                      0
# 416                             0                      0
# 72                              0                      0
# ...                           ...                    ...
# 2393                            0                      0
# 1415                            0                      1
# 2763                            0                      0
# 3552                            0                      0
# 2335                            0                      0
#
# [4909 rows x 21 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9581635425156207
# Testing Data Score: 0.9560260586319218
# /Users/novakradovic/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=800).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.9560260586319218

# %%
clf
# Out:
# RandomForestClassifier(n_estimators=800, random_state=1)

# %%
import pickle

pickle.dump(clf, open('model.h5', 'wb'))

# %%
loaded_model = pickle.load(open('model.h5', 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9560260586319218

# %%
loaded_model
# Out:
# RandomForestClassifier(n_estimators=800, random_state=1)

# %%
print(loaded_model.predict(X[1:10]))
print(y[1:10])
# Out:
# [0 0 0 0 0 0 0 0 0]
# 2566    0
# 3021    0
# 416     0
# 72      1
# 4452    0
# 4093    0
# 5024    0
# 4611    0
# 1541    0
# Name: stroke, dtype: int64

# %%
import tensorflow as tf
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=8, activation="relu", input_dim=21))
# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=6, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()

nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=60)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 8)                 176
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 237
# Trainable params: 237
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 116/116 [==============================] - 0s 983us/step - loss: 0.6058 - accuracy: 0.6830
# Epoch 2/60
# 116/116 [==============================] - 0s 790us/step - loss: 0.3041 - accuracy: 0.9563
# Epoch 3/60
# 116/116 [==============================] - 0s 793us/step - loss: 0.2071 - accuracy: 0.9579
# Epoch 4/60
# 116/116 [==============================] - 0s 774us/step - loss: 0.1846 - accuracy: 0.9579
# Epoch 5/60
# 116/116 [==============================] - 0s 763us/step - loss: 0.1733 - accuracy: 0.9579
# Epoch 6/60
# 116/116 [==============================] - 0s 840us/step - loss: 0.1664 - accuracy: 0.9579
# Epoch 7/60
# 116/116 [==============================] - 0s 831us/step - loss: 0.1618 - accuracy: 0.9579
# Epoch 8/60
# 116/116 [==============================] - 0s 847us/step - loss: 0.1582 - accuracy: 0.9579
# Epoch 9/60
# 116/116 [==============================] - 0s 812us/step - loss: 0.1552 - accuracy: 0.9579
# Epoch 10/60
# 116/116 [==============================] - 0s 760us/step - loss: 0.1528 - accuracy: 0.9579
# Epoch 11/60
# 116/116 [==============================] - 0s 826us/step - loss: 0.1508 - accuracy: 0.9579
# Epoch 12/60
# 116/116 [==============================] - 0s 840us/step - loss: 0.1492 - accuracy: 0.9579
# Epoch 13/60
# 116/116 [==============================] - 0s 831us/step - loss: 0.1476 - accuracy: 0.9579
# Epoch 14/60
# 116/116 [==============================] - 0s 819us/step - loss: 0.1467 - accuracy: 0.9579
# Epoch 15/60
# 116/116 [==============================] - 0s 806us/step - loss: 0.1453 - accuracy: 0.9579
# Epoch 16/60
# 116/116 [==============================] - 0s 802us/step - loss: 0.1445 - accuracy: 0.9579
# Epoch 17/60
# 116/116 [==============================] - 0s 964us/step - loss: 0.1436 - accuracy: 0.9579
# Epoch 18/60
# 116/116 [==============================] - 0s 799us/step - loss: 0.1428 - accuracy: 0.9579
# Epoch 19/60
# 116/116 [==============================] - 0s 844us/step - loss: 0.1421 - accuracy: 0.9579
# Epoch 20/60
# 116/116 [==============================] - 0s 831us/step - loss: 0.1415 - accuracy: 0.9579
# Epoch 21/60
# 116/116 [==============================] - 0s 790us/step - loss: 0.1409 - accuracy: 0.9579
# Epoch 22/60
# 116/116 [==============================] - 0s 866us/step - loss: 0.1405 - accuracy: 0.9579
# Epoch 23/60
# 116/116 [==============================] - 0s 849us/step - loss: 0.1398 - accuracy: 0.9579
# Epoch 24/60
# 116/116 [==============================] - 0s 820us/step - loss: 0.1394 - accuracy: 0.9579
# Epoch 25/60
# 116/116 [==============================] - 0s 801us/step - loss: 0.1403 - accuracy: 0.9579
# Epoch 26/60
# 116/116 [==============================] - 0s 777us/step - loss: 0.1391 - accuracy: 0.9579
# Epoch 27/60
# 116/116 [==============================] - 0s 796us/step - loss: 0.1385 - accuracy: 0.9579
# Epoch 28/60
# 116/116 [==============================] - 0s 788us/step - loss: 0.1379 - accuracy: 0.9579
# Epoch 29/60
# 116/116 [==============================] - 0s 844us/step - loss: 0.1375 - accuracy: 0.9579
# Epoch 30/60
# 116/116 [==============================] - 0s 802us/step - loss: 0.1371 - accuracy: 0.9579
# Epoch 31/60
# 116/116 [==============================] - 0s 822us/step - loss: 0.1368 - accuracy: 0.9579
# Epoch 32/60
# 116/116 [==============================] - 0s 769us/step - loss: 0.1364 - accuracy: 0.9579
# Epoch 33/60
# 116/116 [==============================] - 0s 785us/step - loss: 0.1361 - accuracy: 0.9579
# Epoch 34/60
# 116/116 [==============================] - 0s 786us/step - loss: 0.1360 - accuracy: 0.9579
# Epoch 35/60
# 116/116 [==============================] - 0s 799us/step - loss: 0.1359 - accuracy: 0.9579
# Epoch 36/60
# 116/116 [==============================] - 0s 792us/step - loss: 0.1354 - accuracy: 0.9579
# Epoch 37/60
# 116/116 [==============================] - 0s 802us/step - loss: 0.1353 - accuracy: 0.9579
# Epoch 38/60
# 116/116 [==============================] - 0s 823us/step - loss: 0.1350 - accuracy: 0.9579
# Epoch 39/60
# 116/116 [==============================] - 0s 813us/step - loss: 0.1347 - accuracy: 0.9579
# Epoch 40/60
# 116/116 [==============================] - 0s 788us/step - loss: 0.1346 - accuracy: 0.9579
# Epoch 41/60
# 116/116 [==============================] - 0s 857us/step - loss: 0.1344 - accuracy: 0.9579
# Epoch 42/60
# 116/116 [==============================] - 0s 786us/step - loss: 0.1345 - accuracy: 0.9579
# Epoch 43/60
# 116/116 [==============================] - 0s 813us/step - loss: 0.1340 - accuracy: 0.9579
# Epoch 44/60
# 116/116 [==============================] - 0s 870us/step - loss: 0.1340 - accuracy: 0.9579
# Epoch 45/60
# 116/116 [==============================] - 0s 869us/step - loss: 0.1338 - accuracy: 0.9579
# Epoch 46/60
# 116/116 [==============================] - 0s 843us/step - loss: 0.1335 - accuracy: 0.9579
# Epoch 47/60
# 116/116 [==============================] - 0s 828us/step - loss: 0.1332 - accuracy: 0.9579
# Epoch 48/60
# 116/116 [==============================] - 0s 830us/step - loss: 0.1332 - accuracy: 0.9579
# Epoch 49/60
# 116/116 [==============================] - 0s 738us/step - loss: 0.1329 - accuracy: 0.9579
# Epoch 50/60
# 116/116 [==============================] - 0s 776us/step - loss: 0.1328 - accuracy: 0.9579
# Epoch 51/60
# 116/116 [==============================] - 0s 769us/step - loss: 0.1326 - accuracy: 0.9576
# Epoch 52/60
# 116/116 [==============================] - 0s 754us/step - loss: 0.1322 - accuracy: 0.9579
# Epoch 53/60
# 116/116 [==============================] - 0s 721us/step - loss: 0.1322 - accuracy: 0.9579
# Epoch 54/60
# 116/116 [==============================] - 0s 754us/step - loss: 0.1319 - accuracy: 0.9579
# Epoch 55/60
# 116/116 [==============================] - 0s 751us/step - loss: 0.1319 - accuracy: 0.9576
# Epoch 56/60
# 116/116 [==============================] - 0s 728us/step - loss: 0.1315 - accuracy: 0.9576
# Epoch 57/60
# 116/116 [==============================] - 0s 764us/step - loss: 0.1318 - accuracy: 0.9579
# Epoch 58/60
# 116/116 [==============================] - 0s 755us/step - loss: 0.1316 - accuracy: 0.9579
# Epoch 59/60
# 116/116 [==============================] - 0s 755us/step - loss: 0.1313 - accuracy: 0.9573
# Epoch 60/60
# 116/116 [==============================] - 0s 773us/step - loss: 0.1310 - accuracy: 0.9579

# %%
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 39/39 - 0s - loss: 0.1480 - accuracy: 0.9560
# Loss: 0.14798589050769806, Accuracy: 0.9560260772705078

# %%
nn_model.save('nn_model.h5')

# %%
from tensorflow.keras.models import load_model
model = load_model("nn_model.h5")
model

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 39/39 - 0s - loss: 0.1480 - accuracy: 0.9560
# Loss: 0.14798589050769806, Accuracy: 0.9560260772705078

# %%
print(model.predict(X[0:6]).round())
print(y)
# Out:
# [[1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]]
# 4874    0
# 2566    0
# 3021    0
# 416     0
# 72      1
#        ..
# 2393    0
# 1415    0
# 2763    0
# 3552    0
# 2335    0
# Name: stroke, Length: 4909, dtype: int64
