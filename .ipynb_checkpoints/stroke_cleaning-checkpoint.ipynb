# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('clean_data.csv')
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0      Female  50.0             0              0          Yes  Self-employed
# 1        Male  47.0             0              1          Yes        Private
# 2        Male  42.0             1              0          Yes        Private
# 3      Female  20.0             0              0           No        Private
# 4        Male  62.0             1              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 29060  Female  82.0             0              0           No        Private
# 29061    Male  79.0             0              0          Yes        Private
# 29062    Male  72.0             0              0          Yes  Self-employed
# 29063  Female  61.0             0              0          Yes  Self-employed
# 29064    Male  79.0             0              0          Yes        Private
#
#       residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0              Urban             114.76  20.8     never smoked       0
# 1              Urban              82.79  33.7  formerly smoked       0
# 2              Urban              72.22  28.6           smokes       0
# 3              Urban             177.57  18.4     never smoked       0
# 4              Rural             125.90  33.2  formerly smoked       0
# ...              ...                ...   ...              ...     ...
# 29060          Urban              87.19  24.3     never smoked       0
# 29061          Rural              87.09  26.6  formerly smoked       0
# 29062          Urban              87.29  30.8           smokes       0
# 29063          Urban             205.82  27.5  formerly smoked       0
# 29064          Urban              96.63  29.9     never smoked       0
#
# [29065 rows x 11 columns]

# %%
df.nunique()

# %%
df.smoking_status.value_counts()

# %%
df.isnull().sum()

# %%
df.stroke.value_counts()

# %%
df = df.drop(['id'], axis = 1)
df = df.dropna()
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 1        Male  58.0             1              0          Yes        Private
# 3      Female  70.0             0              0          Yes        Private
# 6      Female  52.0             0              0          Yes        Private
# 7      Female  75.0             0              1          Yes  Self-employed
# 8      Female  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 43395  Female  10.0             0              0           No       children
# 43396  Female  56.0             0              0          Yes       Govt_job
# 43397  Female  82.0             1              0          Yes        Private
# 43398    Male  40.0             0              0          Yes        Private
# 43399  Female  82.0             0              0          Yes        Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 1              Urban              87.96  39.2     never smoked       0
# 3              Rural              69.04  35.9  formerly smoked       0
# 6              Urban              77.59  17.7  formerly smoked       0
# 7              Rural             243.53  27.0     never smoked       0
# 8              Rural              77.67  32.3           smokes       0
# ...              ...                ...   ...              ...     ...
# 43395          Urban              58.64  20.4     never smoked       0
# 43396          Urban             213.61  55.4  formerly smoked       0
# 43397          Urban              91.94  28.9  formerly smoked       0
# 43398          Urban              99.16  33.2     never smoked       0
# 43399          Urban              79.48  20.6     never smoked       0
#
# [29072 rows x 11 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df = df.rename(columns={'Residence_type': 'residence_type'})
df = df.loc[df.gender != 'Other']

# %%
df.to_csv('clean_data.csv', index=False)

# %%
df.dtypes

# %%
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table
import psycopg2
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, Float

connection_string = "postgres:postgres@localhost:5432/stroke_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()

# %%
df.to_sql(name="stroke_data", con=engine, if_exists='append', index=False)

# %%
df.head(40)
# Out:
#     gender   age  hypertension  heart_disease ever_married      work_type  \
# 0   Female  26.0             0              0           No        Private
# 1     Male  71.0             1              0          Yes        Private
# 2   Female  46.0             0              0          Yes        Private
# 3   Female  52.0             0              0          Yes        Private
# 4     Male  67.0             0              0          Yes        Private
# 5   Female  43.0             0              0          Yes  Self-employed
# 6     Male  16.0             0              0           No        Private
# 7   Female  76.0             0              0          Yes        Private
# 8     Male  61.0             0              0          Yes        Private
# 9   Female  21.0             0              0           No   Never_worked
# 10  Female  67.0             0              0          Yes  Self-employed
# 11    Male  20.0             0              0           No       Govt_job
# 12  Female  31.0             0              0          Yes        Private
# 13  Female  23.0             0              0          Yes        Private
# 14    Male  43.0             0              0          Yes        Private
# 15  Female  59.0             1              0           No        Private
# 16  Female  22.0             0              0           No        Private
# 17    Male  61.0             0              0          Yes        Private
# 18    Male  44.0             0              0           No        Private
# 19  Female  22.0             0              0           No        Private
# 20  Female  26.0             0              0           No        Private
# 21  Female  24.0             0              0           No        Private
# 22    Male  81.0             0              0          Yes        Private
# 23    Male  47.0             0              0          Yes        Private
# 24    Male  57.0             0              0          Yes        Private
# 25  Female  47.0             0              0          Yes  Self-employed
# 26  Female  78.0             0              1          Yes       Govt_job
# 27  Female  50.0             0              0          Yes        Private
# 28    Male  51.0             0              0          Yes        Private
# 29  Female  27.0             0              0           No        Private
# 30    Male  40.0             0              0          Yes        Private
# 31  Female  46.0             0              0          Yes        Private
# 32    Male  64.0             0              0          Yes       Govt_job
# 33    Male  70.0             0              0          Yes        Private
# 34  Female  59.0             0              0          Yes        Private
# 35    Male  32.0             0              0           No  Self-employed
# 36  Female  40.0             0              0          Yes        Private
# 37  Female  68.0             0              0          Yes       Govt_job
# 38    Male  11.0             0              0           No       children
# 39  Female  57.0             0              0          Yes       Govt_job
#
#    residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0           Rural              78.05  30.8     never smoked       0
# 1           Urban             108.70  31.2           smokes       0
# 2           Urban             201.42  50.8           smokes       0
# 3           Rural             124.27  22.2           smokes       0
# 4           Rural              95.48  30.1  formerly smoked       0
# 5           Rural             236.67  38.3           smokes       0
# 6           Rural              69.13  22.4  formerly smoked       0
# 7           Rural              96.63  27.8  formerly smoked       0
# 8           Rural              57.63  32.7  formerly smoked       0
# 9           Rural              89.52  36.5  formerly smoked       0
# 10          Urban              63.72  31.9     never smoked       0
# 11          Rural              73.35  33.1     never smoked       0
# 12          Rural             141.14  28.1     never smoked       0
# 13          Urban              79.84  23.3     never smoked       0
# 14          Urban             112.28  28.7     never smoked       0
# 15          Rural             109.05  29.4     never smoked       0
# 16          Rural             114.98  22.7     never smoked       0
# 17          Rural             103.78  39.6  formerly smoked       0
# 18          Urban             103.44  28.0     never smoked       0
# 19          Rural             108.40  24.8     never smoked       0
# 20          Rural             110.72  28.8     never smoked       0
# 21          Urban              96.06  22.6  formerly smoked       0
# 22          Rural             113.13  19.8     never smoked       0
# 23          Urban              68.36  34.1     never smoked       0
# 24          Urban             117.45  24.4     never smoked       0
# 25          Urban             117.17  31.1  formerly smoked       0
# 26          Urban             212.62  26.5     never smoked       1
# 27          Rural              68.41  23.9           smokes       0
# 28          Rural              78.29  30.8     never smoked       0
# 29          Urban              99.34  23.4     never smoked       0
# 30          Rural             117.49  33.4           smokes       0
# 31          Urban              69.16  27.9  formerly smoked       0
# 32          Rural             187.87  32.3     never smoked       0
# 33          Rural             238.10  29.1     never smoked       0
# 34          Urban              69.36  26.7           smokes       0
# 35          Rural              75.86  26.4           smokes       0
# 36          Urban             103.58  32.1           smokes       0
# 37          Urban              57.24  25.8           smokes       0
# 38          Urban              70.72  20.4     never smoked       0
# 39          Urban             109.12  41.4     never smoked       0

# %%
df['ever_married'] = LabelEncoder().fit_transform(df['ever_married'])
df['residence_type'] = LabelEncoder().fit_transform(df['residence_type'])
df['gender'] = LabelEncoder().fit_transform(df['gender'])
df['work_type'] = LabelEncoder().fit_transform(df['work_type'])
df['smoking_status'] = LabelEncoder().fit_transform(df['smoking_status'])

# %%
# df = pd.get_dummies(df, columns = ['work_type', 'smoking_status'])
df.head(40)
# Out:
#     gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0        0  26.0             0              0             0          2
# 1        1  71.0             1              0             1          2
# 2        0  46.0             0              0             1          2
# 3        0  52.0             0              0             1          2
# 4        1  67.0             0              0             1          2
# 5        0  43.0             0              0             1          3
# 6        1  16.0             0              0             0          2
# 7        0  76.0             0              0             1          2
# 8        1  61.0             0              0             1          2
# 9        0  21.0             0              0             0          1
# 10       0  67.0             0              0             1          3
# 11       1  20.0             0              0             0          0
# 12       0  31.0             0              0             1          2
# 13       0  23.0             0              0             1          2
# 14       1  43.0             0              0             1          2
# 15       0  59.0             1              0             0          2
# 16       0  22.0             0              0             0          2
# 17       1  61.0             0              0             1          2
# 18       1  44.0             0              0             0          2
# 19       0  22.0             0              0             0          2
# 20       0  26.0             0              0             0          2
# 21       0  24.0             0              0             0          2
# 22       1  81.0             0              0             1          2
# 23       1  47.0             0              0             1          2
# 24       1  57.0             0              0             1          2
# 25       0  47.0             0              0             1          3
# 26       0  78.0             0              1             1          0
# 27       0  50.0             0              0             1          2
# 28       1  51.0             0              0             1          2
# 29       0  27.0             0              0             0          2
# 30       1  40.0             0              0             1          2
# 31       0  46.0             0              0             1          2
# 32       1  64.0             0              0             1          0
# 33       1  70.0             0              0             1          2
# 34       0  59.0             0              0             1          2
# 35       1  32.0             0              0             0          3
# 36       0  40.0             0              0             1          2
# 37       0  68.0             0              0             1          0
# 38       1  11.0             0              0             0          4
# 39       0  57.0             0              0             1          0
#
#     residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                0              78.05  30.8               1       0
# 1                1             108.70  31.2               2       0
# 2                1             201.42  50.8               2       0
# 3                0             124.27  22.2               2       0
# 4                0              95.48  30.1               0       0
# 5                0             236.67  38.3               2       0
# 6                0              69.13  22.4               0       0
# 7                0              96.63  27.8               0       0
# 8                0              57.63  32.7               0       0
# 9                0              89.52  36.5               0       0
# 10               1              63.72  31.9               1       0
# 11               0              73.35  33.1               1       0
# 12               0             141.14  28.1               1       0
# 13               1              79.84  23.3               1       0
# 14               1             112.28  28.7               1       0
# 15               0             109.05  29.4               1       0
# 16               0             114.98  22.7               1       0
# 17               0             103.78  39.6               0       0
# 18               1             103.44  28.0               1       0
# 19               0             108.40  24.8               1       0
# 20               0             110.72  28.8               1       0
# 21               1              96.06  22.6               0       0
# 22               0             113.13  19.8               1       0
# 23               1              68.36  34.1               1       0
# 24               1             117.45  24.4               1       0
# 25               1             117.17  31.1               0       0
# 26               1             212.62  26.5               1       1
# 27               0              68.41  23.9               2       0
# 28               0              78.29  30.8               1       0
# 29               1              99.34  23.4               1       0
# 30               0             117.49  33.4               2       0
# 31               1              69.16  27.9               0       0
# 32               0             187.87  32.3               1       0
# 33               0             238.10  29.1               1       0
# 34               1              69.36  26.7               2       0
# 35               0              75.86  26.4               2       0
# 36               1             103.58  32.1               2       0
# 37               1              57.24  25.8               2       0
# 38               1              70.72  20.4               1       0
# 39               1             109.12  41.4               1       0

# %%
df.to_csv('model2_clean_data.csv', index=False)

# %%
df[0:1]
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       0  26.0             0              0             0          2
#
#    residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               0              78.05  30.8               1       0

# %%
df.corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.257536       0.247430           0.228283
# hypertension       0.257536      1.000000       0.117962           0.154052
# heart_disease      0.247430      0.117962       1.000000           0.137482
# avg_glucose_level  0.228283      0.154052       0.137482           1.000000
# bmi                0.106226      0.129283       0.022740           0.176936
# stroke             0.154059      0.078674       0.105142           0.075447
#
#                         bmi    stroke
# age                0.106226  0.154059
# hypertension       0.129283  0.078674
# heart_disease      0.022740  0.105142
# avg_glucose_level  0.176936  0.075447
# bmi                1.000000 -0.004039
# stroke            -0.004039  1.000000

# %%
sns.heatmap(df.corr(), cmap='coolwarm', linecolor='black')
plt.savefig('heatmap.png')
